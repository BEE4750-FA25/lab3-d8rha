# %% [markdown]
# # BEE 4750 Lab 3: Linear Programming with JuMP
#
# **Name**:
#
# **ID**:
#
# > **Due Date**
# >
# > Thursday, 10/23/24, 9:00pm
#
# ## Setup
#
# The following code should go at the top of most Julia scripts; it will
# load the local package environment and install any needed packages. You
# will see this often and shouldn’t need to touch it.

# %%
import Pkg
Pkg.activate(".")
Pkg.instantiate()
# Out:
#   Activating project at `~/4750/lab3-d8rha`
#    Installed IrrationalConstants ── v0.2.6
#    Installed HiGHS_jll ──────────── v1.11.0+1
#    Installed LoggingExtras ──────── v1.2.0
#    Installed MutableArithmetics ─── v1.6.6
#    Installed SpecialFunctions ───── v2.6.1
#    Installed JSON ───────────────── v1.2.0
#    Installed HTTP ───────────────── v1.10.19
#    Installed CodecBzip2 ─────────── v0.8.5
#    Installed BenchmarkTools ─────── v1.6.2
#    Installed MathOptInterface ───── v1.46.0
#    Installed StaticArraysCore ───── v1.4.3
#    Installed CommonSubexpressions ─ v0.3.1
#    Installed Compat ─────────────── v4.18.1
#    Installed StructTypes ────────── v1.11.0
#    Installed libaom_jll ─────────── v3.13.1+0
#    Installed DiffRules ──────────── v1.15.1
#    Installed JSON3 ──────────────── v1.14.3
#    Installed Expat_jll ──────────── v2.7.3+0
#    Installed OpenSSL_jll ────────── v3.5.4+0
#    Installed DiffResults ────────── v1.1.0
#    Installed HiGHS ──────────────── v1.19.3
#    Installed Qt6Wayland_jll ─────── v6.8.2+2
#    Installed Qt6Base_jll ────────── v6.8.2+2
#    Installed MathOptIIS ─────────── v0.1.1
#    Installed StructUtils ────────── v2.5.1
#    Installed ForwardDiff ────────── v1.2.2
#    Installed JuMP ───────────────── v1.29.1
# Precompiling project...
#    1425.9 ms  ✓ StaticArraysCore
#    1435.1 ms  ✓ CommonSubexpressions
#    1998.2 ms  ✓ StructTypes
#    2823.2 ms  ✓ IrrationalConstants
#    1204.8 ms  ✓ LoggingExtras
#    1680.7 ms  ✓ StructUtils
#    1801.0 ms  ✓ Preferences
#    1576.1 ms  ✓ Compat
#    1581.3 ms  ✓ DiffResults
#    4839.1 ms  ✓ DataStructures
#    1851.6 ms  ✓ LogExpFunctions
#    1072.8 ms  ✓ PrecompileTools
#    1647.7 ms  ✓ JLLWrappers
#    1579.4 ms  ✓ Compat → CompatLinearAlgebraExt
#    1615.0 ms  ✓ SortingAlgorithms
#    1774.6 ms  ✓ OpenSSL_jll
#    3819.0 ms  ✓ RecipesBase
#    1057.1 ms  ✓ Graphite2_jll
#     979.0 ms  ✓ Libmount_jll
#     959.3 ms  ✓ EpollShim_jll
#    1152.0 ms  ✓ LLVMOpenMP_jll
#    1398.2 ms  ✓ Bzip2_jll
#    1190.5 ms  ✓ Xorg_libICE_jll
#     969.7 ms  ✓ Xorg_libXau_jll
#    1251.4 ms  ✓ libpng_jll
#    1404.2 ms  ✓ libfdk_aac_jll
#    1500.1 ms  ✓ LAME_jll
#   13469.3 ms  ✓ MutableArithmetics
#    1271.7 ms  ✓ LERC_jll
#    1091.7 ms  ✓ fzf_jll
#   10835.0 ms  ✓ ColorSchemes
#    1182.7 ms  ✓ XZ_jll
#    1193.2 ms  ✓ JpegTurbo_jll
#    1030.1 ms  ✓ Ogg_jll
#     921.2 ms  ✓ mtdev_jll
#     904.2 ms  ✓ Xorg_libXdmcp_jll
#    1043.1 ms  ✓ x265_jll
#    1099.3 ms  ✓ x264_jll
#    1123.1 ms  ✓ libaom_jll
#    1114.6 ms  ✓ Zstd_jll
#    1085.1 ms  ✓ Expat_jll
#    1080.2 ms  ✓ LZO_jll
#     947.5 ms  ✓ Xorg_xtrans_jll
#    1067.1 ms  ✓ Opus_jll
#     952.0 ms  ✓ libevdev_jll
#    1127.6 ms  ✓ Libiconv_jll
#     970.9 ms  ✓ eudev_jll
#    1072.9 ms  ✓ Libffi_jll
#    1136.6 ms  ✓ OpenSpecFun_jll
#    1015.5 ms  ✓ Libuuid_jll
#    1198.2 ms  ✓ FriBidi_jll
#    1319.5 ms  ✓ HiGHS_jll
#    2220.4 ms  ✓ Pixman_jll
#    2430.6 ms  ✓ FreeType2_jll
#    1168.3 ms  ✓ CodecBzip2
#    1004.1 ms  ✓ Xorg_libSM_jll
#    6233.4 ms  ✓ StatsBase
#    2147.9 ms  ✓ JLFzf
#    6798.9 ms  ✓ OpenSSL
#     906.9 ms  ✓ Xorg_libxcb_jll
#    1749.7 ms  ✓ libvorbis_jll
#    2670.5 ms  ✓ Ghostscript_jll
#     969.1 ms  ✓ Dbus_jll
#    1083.1 ms  ✓ libinput_jll
#   26562.3 ms  ✓ Parsers
#    2253.9 ms  ✓ GettextRuntime_jll
#     953.2 ms  ✓ Wayland_jll
#    3021.0 ms  ✓ Libtiff_jll
#    1347.0 ms  ✓ Xorg_xcb_util_jll
#    3038.7 ms  ✓ Xorg_libX11_jll
#    6353.4 ms  ✓ Fontconfig_jll
#    9450.9 ms  ✓ SpecialFunctions
#   10451.5 ms  ✓ Latexify
#    3070.8 ms  ✓ Glib_jll
#    1163.0 ms  ✓ Xorg_xcb_util_image_jll
#   10642.4 ms  ✓ JSON
#    1112.7 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1276.0 ms  ✓ Xorg_xcb_util_renderutil_jll
#   28044.9 ms  ✓ PlotUtils
#    1219.3 ms  ✓ Xorg_xcb_util_wm_jll
#    1047.4 ms  ✓ Xorg_libXrender_jll
#    1090.2 ms  ✓ Xorg_libXext_jll
#    1131.6 ms  ✓ Xorg_libXfixes_jll
#    1204.5 ms  ✓ Xorg_libxkbfile_jll
#    2218.8 ms  ✓ DiffRules
#    2465.5 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    1346.8 ms  ✓ Xorg_xcb_util_cursor_jll
#    3136.5 ms  ✓ Latexify → SparseArraysExt
#   22057.2 ms  ✓ JSON3
#    4397.5 ms  ✓ BenchmarkTools
#    1086.2 ms  ✓ Xorg_libXinerama_jll
#    1166.7 ms  ✓ Xorg_libXrandr_jll
#    1204.0 ms  ✓ Libglvnd_jll
#    1055.6 ms  ✓ Xorg_libXcursor_jll
#    1345.1 ms  ✓ Xorg_libXi_jll
#    1173.4 ms  ✓ Xorg_xkbcomp_jll
#    8034.5 ms  ✓ PlotThemes
#    4000.4 ms  ✓ Cairo_jll
#    1896.5 ms  ✓ Xorg_xkeyboard_config_jll
#   10702.4 ms  ✓ RecipesPipeline
#     950.6 ms  ✓ xkbcommon_jll
#    2941.1 ms  ✓ HarfBuzz_jll
#     990.7 ms  ✓ Vulkan_Loader_jll
#    2411.4 ms  ✓ libass_jll
#    2508.4 ms  ✓ Pango_jll
#    1038.1 ms  ✓ libdecor_jll
#    1364.9 ms  ✓ GLFW_jll
#    8189.5 ms  ✓ ForwardDiff
#   12282.3 ms  ✓ Qt6Base_jll
#   11011.4 ms  ✓ FFMPEG_jll
#   51208.3 ms  ✓ HTTP
#    2836.5 ms  ✓ FFMPEG
#    9271.1 ms  ✓ Qt6ShaderTools_jll
#    9101.2 ms  ✓ GR_jll
#    5934.8 ms  ✓ Qt6Declarative_jll
#    1180.1 ms  ✓ Qt6Wayland_jll
#    6232.1 ms  ✓ GR
#   71539.7 ms  ✓ MathOptInterface
#    3401.8 ms  ✓ MathOptIIS
#   22435.2 ms  ✓ HiGHS
#   34853.4 ms  ✓ JuMP
#   87242.2 ms  ✓ Plots
#   122 dependencies successfully precompiled in 196 seconds. 75 already precompiled.

# %%
using JuMP # optimization modeling syntax
using HiGHS # optimization solver

# %% [markdown]
# ## Overview
#
# In this lab, you will write and solve a resource allocation example
# using `JuMP.jl`. `JuMP.jl` provides an intuitive syntax for writing,
# solving, and querying optimization problems.
#
# `JuMP` requires the loading of a solver. \[Each supported solver works
# for certain classes of problems, and some are open source while others
# require a commercial license\]. We will use the `HiGHS` solver, which is
# open source and works for linear, mixed integer linear, and quadratic
# programs.
#
# In this lab we will walk through the steps involved in coding a linear
# program in HiGHS, solving it, and querying the solution.
#
# ## Exercise (3 points)
#
# Your task is to decide how much lumber to produce to maximize profit
# from wood sales. You can purchase wood from a managed forest, which
# consists of spruce (320,000 bf) and fir (720,000 bf). Spruce costs
# $\$0.12$ per bf to purchase and fir costs $\$0.08$ per bf.
#
# At the lumber mill, wood can be turned into plywood of various grades
# (see <a href="#tbl-inputs" class="quarto-xref">Table 1</a> for how much
# wood of each type is required for and the revenue from each grade). Any
# excess wood is sent to be recycled into particle board, which yields no
# revenue for the mill.
#
# | Plywood Grade | Inputs (bf/bf plywood) | Revenue (\$/1000 bf) |
# |:-------------:|:----------------------:|:--------------------:|
# |       1       |   0.5 (S) + 1.5 (F)    |         400          |
# |       2       |   1.0 (S) + 2.0 (F)    |         520          |
# |       3       |   1.5 (S) + 2.0 (F)    |         700          |
#
# Table 1: Wood inputs and revenue by plywood grade. S refers to spruce
# inputs, F fir inputs.
#
# First, we need to identify our decision variables. While there are
# several options, we will use $G_i$, the amount of each grade the mill
# produces (in 1000 bf).
#
# Using these decision variables, formulate a linear program to maximize
# the profit of the mill subject to the supply constraints on spruce and
# fir.
#
# > **JuMP Syntax**
# >
# > The core pieces of setting up a `JuMP` model involve specifying the
# > model and adding variables, the objective, and constraints. At the
# > most simple level, this syntax looks like this:
# >
# > ``` julia
# > m = Model(HiGHS.Optimizer)
# > @variable(m, lb <= x <= ub) # if you do not have upper or lower bounds, you can drop those accordingly
# > @variable(m, lb <= y <= ub)
# > @objective(m, Max, 100x + 250y) # replace Max with Min depending on the problem
# > @constraint(m, label, 6x + 12y <= 80) # replace "label" with some meaningful string you would like to use later to query shadow prices, or drop it
# > ```
# >
# > You can add more constraints or more variables as needed.
#
# > **Using Array Syntax**
# >
# > You can set up multiple variables or constraints at once using array
# > syntax. For example, the following are equivalent:
# >
# > ``` julia
# > @variable(m, G1 >= 0)
# > @variable(m, G2 >= 0)
# > @variable(m, G3 >= 0)
# > ```
# >
# > and
# >
# > ``` julia
# > @variable(m, G[1:3] >= 0)
# > ```
# >
# > You can also set up multiple constraints using arrays of coefficients
# > and/or bounds. For example:
# >
# > ``` julia
# > I = 1:3
# > d = [0; 3; 5]
# > @constraint(m, demand[i in I], G[i] >= d[i])
# > ```
#
# `JuMP` is finicky about changing objects and constraints, so I recommend
# setting up all of the model syntax in one notebook cell, which is what
# we will do here.

# %%
forest_model = Model(HiGHS.Optimizer) # initialize model object
@variable(forest_model, G[1:3] >= 0) # non-negativity constraints
# uncomment the following lines and add the objective and constraints as needed for the model
# @objective(forest_model, Max, (400 - 1000(0.5*0.12 + 1.5*0.08))*G[1] + (520 - 1000(1.0*0.12 + 2.0*0.08))*G[2] + (700 - 1000(1.5*0.12 + 2.0*0.08))*G[3]) since profit = revenue - cost
@objective(forest_model, Max, (220)*G[1] + (240)*G[2] + (360)*G[3])
@constraint(forest_model, max_spruce_material, 0.5*G[1] + 1.0*G[2] + 1.5*G[3] <= 320)
@constraint(forest_model, max_fir_material, 1.5*G[1] + 2.0*G[2] + 2.0*G[3] <= 720)

print(forest_model) # this outputs a nicely formatted summary of the model so you can check your specification
# Out:
# Max 220 G[1] + 240 G[2] + 360 G[3]
# Subject to
#  max_spruce_material : 0.5 G[1] + G[2] + 1.5 G[3] ≤ 320
#  max_fir_material : 1.5 G[1] + 2 G[2] + 2 G[3] ≤ 720
#  G[1] ≥ 0
#  G[2] ≥ 0
#  G[3] ≥ 0

# %% [markdown]
# Next, to optimize, use the `optimize!()` function:

# %%
optimize!(forest_model)
# Out:
# Running HiGHS 1.11.0 (git hash: 364c83a51e): Copyright (c) 2025 HiGHS under MIT licence terms
# LP   has 2 rows; 3 cols; 6 nonzeros
# Coefficient ranges:
#   Matrix [5e-01, 2e+00]
#   Cost   [2e+02, 4e+02]
#   Bound  [0e+00, 0e+00]
#   RHS    [3e+02, 7e+02]
# Presolving model
# 2 rows, 3 cols, 6 nonzeros  0s
# 2 rows, 3 cols, 6 nonzeros  0s
# Presolve : Reductions: rows 2(-0); columns 3(-0); elements 6(-0) - Not reduced
# Problem not reduced by presolve: solving the LP
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -8.1999929744e+02 Ph1: 2(8.5); Du: 3(819.999) 0s
#           2     1.1200000000e+05 Pr: 0(0) 0s
# Model status        : Optimal
# Simplex   iterations: 2
# Objective value     :  1.1200000000e+05
# P-D objective error :  0.0000000000e+00
# HiGHS run time      :          0.00

# %% [markdown]
# You should get confirmation that a solution was found; if one was not,
# there’s a chance something was wrong with your model formulation.
#
# To find the values of the decision variables, use `value()` (which can
# be broadcasted over variable arrays):

# %%
@show value.(G);
# Out:
# value.(G) = [352.0, 0.0, 96.0]

# %% [markdown]
# Similarly, `objective_value()` finds the optimal value of the objective:

# %%
@show objective_value(forest_model);
# Out:
# objective_value(forest_model) = 112000.0

# %% [markdown]
# Finally, we can find the dual values of the constraints with
# `shadow_price()`. Do this for the constraints in your model using the
# block below.

# %%
@show shadow_price(max_spruce_material);
@show shadow_price(max_fir_material);
# Out:
# shadow_price(max_spruce_material) = 80.0
# shadow_price(max_fir_material) = 120.0

# %% [markdown]
# `JuMP` also lets you evaluate other expressions that you might be
# interested in based on the solutions. For example, you can use the
# following block to calculate the total amount of plywood the mill would
# produce under the optimal solution:

# %%
@expression(forest_model, total_plywood, sum(G))
@show value.(total_plywood);
# Out:
# value.(total_plywood) = 448.0

# %% [markdown]
# ## References
#
# Put any consulted sources here, including classmates you worked with/who
# helped you.

# %% [markdown]
# I consulted with Evan Sims (ems452) to help me understand the logic of setting up the constraints so that the maximum amount of each material of wood was based on each proportion for each plywood grade.
